# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\emmap\Downloads\world_population.csv")
df.head(5)
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia      41128771.00
# 1   138  ALB         Albania            Tirana    Europe       2842321.00
# 2    34  DZA         Algeria           Algiers    Africa      44903225.00
# 3   213  ASM  American Samoa         Pago Pago   Oceania         44273.00
# 4   203  AND         Andorra  Andorra la Vella    Europe         79824.00
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0      38972230.00      33753499.00      28189672.00      19542982.00
# 1       2866849.00       2882481.00       2913399.00       3182021.00
# 2      43451666.00      39543154.00      35856344.00      30774621.00
# 3         46189.00         51368.00         54849.00         58230.00
# 4         77700.00         71746.00         71519.00         66097.00
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
# change decimal format
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
## quick overview
# we can see starting at '2022 Population', there are missing values
df.info()
# statistical overview
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              230 non-null    float64
#  6   2020 Population              233 non-null    float64
#  7   2015 Population              230 non-null    float64
#  8   2010 Population              227 non-null    float64
#  9   2000 Population              227 non-null    float64
#  10  1990 Population              229 non-null    float64
#  11  1980 Population              229 non-null    float64
# ...

# %%
# find null values
null_values_sum = df.isnull().sum()
# gives how many unique values in each column
# good way to check data accuracy
unique_values_sum = df.nunique()

print(null_values_sum)
print(unique_values_sum)
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                4
# 2020 Population                1
# 2015 Population                4
# 2010 Population                7
# 2000 Population                7
# 1990 Population                5
# 1980 Population                5
# 1970 Population                4
# Area (km²)                     2
# Density (per km²)              4
# Growth Rate                    2
# World Population Percentage    0
# dtype: int64
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                        6
# 2022 Population                230
# 2020 Population                233
# 2015 Population                230
# 2010 Population                227
# 2000 Population                227
# ...

# %%
# Q: sort 2022 data to find top 10 populated countries
df.sort_values(by="2022 Population", ascending=False).head(10)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41     1425887337.00    1424929781.00    1393715448.00    1348191368.00
# 92     1417173173.00    1396387127.00    1322866505.00    1240613620.00
# ...

# %%
# finding correlations in data
# df.corr() gives error
# must filter data to only have numeric data

numeric_data = df.select_dtypes(include='number')
numeric_data.corr()
# Out:
#                              Rank  2022 Population  2020 Population  \
# Rank                         1.00            -0.36            -0.36
# 2022 Population             -0.36             1.00             1.00
# 2020 Population             -0.36             1.00             1.00
# 2015 Population             -0.35             1.00             1.00
# 2010 Population             -0.35             1.00             1.00
# 2000 Population             -0.34             0.99             1.00
# 1990 Population             -0.33             0.99             0.99
# 1980 Population             -0.33             0.99             0.99
# 1970 Population             -0.34             0.97             0.98
# Area (km²)                  -0.38             0.45             0.45
# Density (per km²)            0.13            -0.03            -0.03
# Growth Rate                 -0.22            -0.02            -0.03
# World Population Percentage -0.36             1.00             1.00
#
# ...

# %%
# create heatmap visual off of correlation
sns.heatmap(numeric_data.corr(), annot=True)
plt.rcParams['figure.figsize']=(20,7)
plt.show # jupyter notebooks usually auto shows graphs but should do anyways
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# finding Oceania nations
df[df['Continent'].str.contains('Oceania')].head(5)
# OR
df[df['Continent'] == 'Oceania'].head(5)
# OR
df.query("Continent == 'Oceania'").head(5)
# Out:
#     Rank CCA3           Country    Capital Continent  2022 Population  \
# 3    213  ASM    American Samoa  Pago Pago   Oceania         44273.00
# 11    55  AUS         Australia   Canberra   Oceania      26177413.00
# 44   223  COK      Cook Islands     Avarua   Oceania         17011.00
# 66   162  FJI              Fiji       Suva   Oceania        929766.00
# 70   183  PYF  French Polynesia    Papeete   Oceania        306279.00
#
#     2020 Population  2015 Population  2010 Population  2000 Population  \
# 3          46189.00         51368.00         54849.00         58230.00
# 11      25670051.00      23820236.00      22019168.00      19017963.00
# 44         17029.00         17695.00         17212.00         15897.00
# 66        920422.00        917200.00        905169.00        832509.00
# 70        301920.00        291787.00        283788.00        250927.00
#
#     1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
# Q: what continents have grown faster than others? How have they grown faster?
avg_pop = df.groupby('Continent').mean(numeric_only=True).sort_values(by='2022 Population', ascending=False)
# transpose for better graphs
transpose_avg_pop = avg_pop.transpose()

# %%
# create graph, but it doesn't look right
transpose_avg_pop.plot()
# need to specify only population columns
graph_df = df.groupby('Continent')[['1970 Population', '1980 Population', '1990 Population',
       '2000 Population', '2010 Population', '2015 Population',
       '2020 Population', '2022 Population']].mean(numeric_only=True).sort_values(by='2022 Population', ascending=False)
# OR use indexing [df.columns[5:13]] instead of typing out [["2022 Pop...
# but this gives backwards dates
trans_graph_df = graph_df.transpose()
trans_graph_df.plot()
# Out:
# <Axes: >
