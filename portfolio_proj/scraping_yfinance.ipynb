# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta
import os

# %%
tickers = ['SPY', 'BND', 'GLD', 'QQQ', 'VTI']

end_date = datetime.today()
start_date = end_date - timedelta(days = 10*365)  # go back ten years

end_date = end_date.strftime('%Y-%m-%d')
start_date = start_date.strftime('%Y-%m-%d')

print(end_date)
print(start_date)
# Out:
# 2025-09-07
# 2015-09-10

# %%
close_df = pd.DataFrame()

for ticker in tickers:
    data = yf.download(ticker, start=start_date, end=end_date)
    if not data.empty:
        close_df[ticker] = data['Close']

close_df.head(10)
# Out:
# /tmp/ipykernel_268859/388039563.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_268859/388039563.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_268859/388039563.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_268859/388039563.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_268859/388039563.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
#                    SPY        BND         GLD        QQQ        VTI
# Date
# 2015-09-10  165.096512  61.153416  106.379997  97.355049  85.570343
# 2015-09-11  165.846710  61.281345  106.160004  97.892899  85.958534
# 2015-09-14  165.231354  61.296383  106.220001  97.596138  85.629395
# 2015-09-15  167.296646  61.040554  105.900002  98.745987  86.709610
# 2015-09-16  168.746521  61.002964  107.309998  99.302361  87.443764
# 2015-09-17  168.367218  61.349022  108.410004  99.339432  87.325638
# 2015-09-18  165.615799  61.522072  109.209999  97.926552  85.941666
# 2015-09-21  166.471664  61.296383  108.529999  98.233315  86.287666
# 2015-09-22  164.310852  61.409298  107.790001  96.764618  85.131538
# 2015-09-23  164.048233  61.409298  108.220001  96.839012  84.962753

# %%
print(os.getcwd())

file_path = "/home/emmapeng/tech_projects/portfolio_datasets/10_year_close_prices.xlsx"
close_df.to_excel(file_path)
# Out:
# /home/emmapeng/tech_projects/portfolio_proj
