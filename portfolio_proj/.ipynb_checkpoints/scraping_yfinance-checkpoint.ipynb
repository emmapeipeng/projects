# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta
import os

# %%
tickers = ['SPY', 'BND', 'GLD', 'QQQ', 'VTI']

end_date = datetime.today()
start_date = end_date - timedelta(days = 3*365)  # go back three years

end_date = end_date.strftime('%Y-%m-%d')
start_date = start_date.strftime('%Y-%m-%d')

print(end_date)
print(start_date)
# Out:
# 2025-09-06
# 2022-09-07

# %%
close_df = pd.DataFrame()

for ticker in tickers:
    data = yf.download(ticker, start=start_date, end=end_date)
    if not data.empty:
        close_df[ticker] = data['Close']

close_df.head(10)
# Out:
# /tmp/ipykernel_105342/388039563.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_105342/388039563.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_105342/388039563.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_105342/388039563.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_105342/388039563.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
#                    SPY        BND         GLD         QQQ         VTI
# Date
# 2022-09-07  381.241302  66.856537  159.940002  293.164368  190.811874
# 2022-09-08  383.733185  66.649002  158.979996  294.684235  192.322876
# 2022-09-09  389.694550  66.621902  159.820007  301.126617  195.516907
# 2022-09-12  393.882904  66.540718  160.630005  304.705780  197.620758
# 2022-09-13  376.755890  66.206833  158.539993  287.996704  189.128799
# 2022-09-14  378.193512  66.288048  157.929993  290.281433  189.865158
# 2022-09-15  373.899780  66.089516  154.979996  285.447174  187.837769
# 2022-09-16  371.047272  66.017342  155.839996  283.701752  186.125977
# 2022-09-19  373.924744  65.972221  155.960007  285.910980  187.445679
# 2022-09-20  369.632690  65.647369  155.070007  283.631989  185.265289

# %%
print(os.getcwd())

file_path = "/home/emmapeng/tech_projects/portfolio_datasets/close_prices.xlsx"
close_df.to_excel(file_path)
# Out:
# /home/emmapeng/tech_projects/portfolio_proj
